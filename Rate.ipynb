# %%
import pandas as pd
import csv 
import os 
import numpy as np

# %%
rate_df = pd.read_csv('Rate.csv')
rate_df
# Out:
#          BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0                2014        AK     21989       HIOS           6
# 1                2014        AK     21989       HIOS           6
# 2                2014        AK     21989       HIOS           6
# 3                2014        AK     21989       HIOS           6
# 4                2014        AK     21989       HIOS           6
# 5                2014        AK     21989       HIOS           6
# 6                2014        AK     21989       HIOS           6
# 7                2014        AK     21989       HIOS           6
# 8                2014        AK     21989       HIOS           6
# 9                2014        AK     21989       HIOS           6
# 10               2014        AK     21989       HIOS           6
# 11               2014        AK     21989       HIOS           6
# 12               2014        AK     21989       HIOS           6
# ...

# %%
new_rate_df= pd.DataFrame(rate_df,columns= ['BusinessYear', 'StateCode','Age','IndividualRate'])
new_rate_df
# Out:
#          BusinessYear StateCode            Age  IndividualRate
# 0                2014        AK           0-20           29.00
# 1                2014        AK  Family Option           36.95
# 2                2014        AK  Family Option           36.95
# 3                2014        AK             21           32.00
# 4                2014        AK             22           32.00
# 5                2014        AK  Family Option           36.95
# 6                2014        AK  Family Option           32.45
# 7                2014        AK             23           32.00
# 8                2014        AK             24           32.00
# 9                2014        AK  Family Option           32.45
# 10               2014        AK  Family Option           32.45
# 11               2014        AK             25           32.00
# 12               2014        AK             26           32.00
# 13               2014        AK             27           32.00
# ...

# %%
new_rate_df_subset = new_rate_df.sample(n=100000)
new_rate_df_subset
# Out:
#         BusinessYear StateCode            Age  IndividualRate
# 181601          2014        AZ             37          293.86
# 266982          2014        FL             42          276.59
# 873619          2014        GA             57           20.35
# 352418          2014        FL             22          231.98
# 966040          2014        IN             47          391.41
# 623497          2014        FL             58           25.36
# 326463          2014        FL             63          674.30
# 678461          2014        FL             44           12.31
# 770593          2014        FL             46           15.99
# 413313          2014        FL             48            0.00
# 109594          2014        AZ             45          414.54
# 668518          2014        FL             28           17.98
# 598046          2014        FL             37           21.41
# 404734          2014        FL             47          370.47
# ...

# %%
new_rate_df_subset.to_csv('clean_rate.csv')

# %%
network_df = pd.read_csv('Network.csv')
network_df
# Out:
#       BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0             2014        AK     21989       HIOS           6
# 1             2014        AK     38344       HIOS           6
# 2             2014        AK     38536       HIOS           2
# 3             2014        AK     42507       HIOS           3
# 4             2014        AK     73836       HIOS           6
# 5             2014        AK     73836       HIOS           6
# 6             2014        AK     74819       HIOS           7
# 7             2014        AK     84859       HIOS           1
# 8             2014        AL     12538       HIOS           8
# 9             2014        AL     12538       HIOS           8
# 10            2014        AL     17540       HIOS           3
# 11            2014        AL     44580       HIOS          10
# 12            2014        AL     44580       HIOS          10
# 13            2014        AL     44580       HIOS          10
# ...

# %%
new_network_df= pd.DataFrame(network_df)
network = new_network_df[ ['StateCode', 'ImportDate','NetworkId','NetworkName','NetworkURL','MarketCoverage'] ]
network
# Out:
#      StateCode           ImportDate NetworkId  \
# 0           AK  2014-03-19 07:06:49    AKN001
# 1           AK  2013-08-28 08:15:53    AKN001
# 2           AK  2013-08-01 12:48:00    AKN001
# 3           AK  2013-09-02 11:39:25    AKN001
# 4           AK  2014-04-18 11:49:29    AKN001
# 5           AK  2014-04-18 11:49:29    AKN002
# 6           AK  2014-01-21 08:29:49    AKN001
# 7           AK  2013-06-06 10:50:48    AKN001
# 8           AL  2014-01-21 08:29:49    ALN001
# 9           AL  2014-01-21 08:29:49    ALN002
# 10          AL  2013-09-02 11:39:25    ALN001
# 11          AL  2014-01-21 08:29:49    ALN001
# 12          AL  2014-01-21 08:29:49    ALN002
# 13          AL  2014-01-21 08:29:49    ALN003
# 14          AL  2013-09-10 14:43:20    ALN001
# 15          AL  2013-06-06 10:50:48    ALN001
# 16          AL  2014-01-17 09:36:20    ALN001
# 17          AL  2014-01-16 07:24:04    ALN001
# 18          AL  2014-01-16 07:24:04    ALN002
# ...

# %%
new_network_df= pd.DataFrame(new_network_df,columns= ['StateCode', 'ImportDate','NetworkId','NetworkName','NetworkURL','MarketCoverage'])
new_network_df
# Out:
#      StateCode           ImportDate NetworkId  \
# 0           AK  2014-03-19 07:06:49    AKN001
# 1           AK  2013-08-28 08:15:53    AKN001
# 2           AK  2013-08-01 12:48:00    AKN001
# 3           AK  2013-09-02 11:39:25    AKN001
# 4           AK  2014-04-18 11:49:29    AKN001
# 5           AK  2014-04-18 11:49:29    AKN002
# 6           AK  2014-01-21 08:29:49    AKN001
# 7           AK  2013-06-06 10:50:48    AKN001
# 8           AL  2014-01-21 08:29:49    ALN001
# 9           AL  2014-01-21 08:29:49    ALN002
# 10          AL  2013-09-02 11:39:25    ALN001
# 11          AL  2014-01-21 08:29:49    ALN001
# 12          AL  2014-01-21 08:29:49    ALN002
# 13          AL  2014-01-21 08:29:49    ALN003
# 14          AL  2013-09-10 14:43:20    ALN001
# 15          AL  2013-06-06 10:50:48    ALN001
# 16          AL  2014-01-17 09:36:20    ALN001
# 17          AL  2014-01-16 07:24:04    ALN001
# 18          AL  2014-01-16 07:24:04    ALN002
# ...

# %%
new_network_df.to_csv('clean_network.csv')

# %%
planAttributes_df = pd.read_csv('PlanAttributes_Update.csv')
planAttributes_df
# Out:
#        BusinessYear                     CSRVariationType  \
# 0              2014       Standard Low Off Exchange Plan
# 1              2014        Standard Low On Exchange Plan
# 2              2014      Standard High Off Exchange Plan
# 3              2014       Standard Low Off Exchange Plan
# 4              2014        Standard Low On Exchange Plan
# 5              2014       Standard High On Exchange Plan
# 6              2014    Standard Bronze Off Exchange Plan
# 7              2014      Standard Gold Off Exchange Plan
# 8              2014       Standard Gold On Exchange Plan
# 9              2014     Standard Bronze On Exchange Plan
# 10             2014     Zero Cost Sharing Plan Variation
# 11             2014       Standard Gold On Exchange Plan
# 12             2014    Standard Silver Off Exchange Plan
# 13             2014     Zero Cost Sharing Plan Variation
# 14             2014       Standard Low Off Exchange Plan
# ...

# %%
new_network_df= pd.DataFrame(planAttributes_df,columns= ['BusinessYear', 'CSRVariationType','TIN','URLForEnrollmentPayment','NetworkURL',])
new_network_df
# Out:
#        BusinessYear                     CSRVariationType         TIN  \
# 0              2014       Standard Low Off Exchange Plan  93-0438772
# 1              2014        Standard Low On Exchange Plan  93-0438772
# 2              2014      Standard High Off Exchange Plan  93-0438772
# 3              2014       Standard Low Off Exchange Plan  93-0438772
# 4              2014        Standard Low On Exchange Plan  93-0438772
# 5              2014       Standard High On Exchange Plan  93-0438772
# 6              2014    Standard Bronze Off Exchange Plan  93-0989307
# 7              2014      Standard Gold Off Exchange Plan  93-0989307
# 8              2014       Standard Gold On Exchange Plan  93-0989307
# 9              2014     Standard Bronze On Exchange Plan  93-0989307
# 10             2014     Zero Cost Sharing Plan Variation  93-0989307
# 11             2014       Standard Gold On Exchange Plan  93-0989307
# 12             2014    Standard Silver Off Exchange Plan  93-0989307
# ...
