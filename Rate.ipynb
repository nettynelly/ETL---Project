# %%
import pandas as pd
import csv 
import os 
import numpy as np

# %%
rate_df = pd.read_csv('Rate.csv')
rate_df.head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum      ImportDate  \
# 0          2014        AK     21989       HIOS           6  3/19/2014 7:06
# 1          2014        AK     21989       HIOS           6  3/19/2014 7:06
# 2          2014        AK     21989       HIOS           6  3/19/2014 7:06
# 3          2014        AK     21989       HIOS           6  3/19/2014 7:06
# 4          2014        AK     21989       HIOS           6  3/19/2014 7:06
#
#    FederalTIN RateEffectiveDate RateExpirationDate          PlanId  \
# 0  93-0438772          1/1/2014         12/31/2014  21989AK0010001
# 1  93-0438772          1/1/2014         12/31/2014  21989AK0020001
# 2  93-0438772          1/1/2014         12/31/2014  21989AK0020001
# 3  93-0438772          1/1/2014         12/31/2014  21989AK0010001
# 4  93-0438772          1/1/2014         12/31/2014  21989AK0010001
#
#     RatingAreaId        Tobacco            Age  IndividualRate  \
# ...

# %%
new_rate_df= pd.DataFrame(rate_df,columns= ['BusinessYear', 'StateCode','Age','IndividualRate','IssuerId','PlanId'])
new_rate_df.drop_duplicates().head()
# Out:
#    BusinessYear  StateCode  Age  IndividualRate  IssuerId  PlanId
# 0           NaN        NaN  NaN             NaN       NaN     NaN

# %%
new_rate_df.to_csv('new_rate_df.csv')

# %%
network_df = pd.read_csv('Network.csv')
network_df.drop_duplicates().head()
# Out:
#    BusinessYear StateCode  IssuerId SourceName  VersionNum  \
# 0          2014        AK     21989       HIOS           6
# 1          2014        AK     38344       HIOS           6
# 2          2014        AK     38536       HIOS           2
# 3          2014        AK     42507       HIOS           3
# 4          2014        AK     73836       HIOS           6
#
#             ImportDate  IssuerId2 StateCode2             NetworkName  \
# 0  2014-03-19 07:06:49      21989         AK             ODS Premier
# 1  2013-08-28 08:15:53      38344         AK            HeritagePlus
# 2  2013-08-01 12:48:00      38536         AK  Lincoln Dental Connect
# 3  2013-09-02 11:39:25      42507         AK   DentalGuard Preferred
# 4  2014-04-18 11:49:29      73836         AK   Moda Plus AK Regional
#
#   NetworkId                                         NetworkURL  RowNumber  \
# 0    AKN001  https://www.modahealth.com/ProviderSearch/face...         13
# ...

# %%
new_network_df= pd.DataFrame(network_df,columns= ['StateCode', 'IssuerId','NetworkId','NetworkName','NetworkURL','MarketCoverage'])
new_network_df.drop_duplicates().head()
# Out:
#   StateCode  IssuerId NetworkId             NetworkName  \
# 0        AK     21989    AKN001             ODS Premier
# 1        AK     38344    AKN001            HeritagePlus
# 2        AK     38536    AKN001  Lincoln Dental Connect
# 3        AK     42507    AKN001   DentalGuard Preferred
# 4        AK     73836    AKN001   Moda Plus AK Regional
#
#                                           NetworkURL MarketCoverage
# 0  https://www.modahealth.com/ProviderSearch/face...            NaN
# 1                https://www.premera.com/wa/visitor/            NaN
# 2  http://lfg.go2dental.com/member/dental_search/...            NaN
# 3  https://www.guardiananytime.com/fpapp/FPWeb/de...            NaN
# 4  https://www.modahealth.com/ProviderSearch/face...            NaN

# %%
new_network_df.to_csv('new_network_df.csv')

# %%
planAttributes_df = pd.read_csv('PlanAttributes_Update.csv')
planAttributes_df.drop_duplicates()
# Out:
#        BusinessYear                     CSRVariationType  \
# 0              2014       Standard Low Off Exchange Plan
# 1              2014        Standard Low On Exchange Plan
# 2              2014      Standard High Off Exchange Plan
# 3              2014       Standard Low Off Exchange Plan
# 4              2014        Standard Low On Exchange Plan
# 5              2014       Standard High On Exchange Plan
# 6              2014    Standard Bronze Off Exchange Plan
# 7              2014      Standard Gold Off Exchange Plan
# 8              2014       Standard Gold On Exchange Plan
# 9              2014     Standard Bronze On Exchange Plan
# 10             2014     Zero Cost Sharing Plan Variation
# 11             2014       Standard Gold On Exchange Plan
# 12             2014    Standard Silver Off Exchange Plan
# 13             2014     Zero Cost Sharing Plan Variation
# 14             2014       Standard Low Off Exchange Plan
# ...

# %%
new_planAttributes_df= pd.DataFrame(planAttributes_df,columns= ['BusinessYear', 'CSRVariationType','HIOSProductId','MarketCoverage','MetalLevel','NetworkId','StateCode'])
new_planAttributes_df.drop_duplicates().head()
# Out:
#    BusinessYear                 CSRVariationType HIOSProductId  \
# 0          2014   Standard Low Off Exchange Plan    21989AK002
# 1          2014    Standard Low On Exchange Plan    21989AK002
# 2          2014  Standard High Off Exchange Plan    21989AK002
# 3          2014   Standard Low Off Exchange Plan    21989AK001
# 4          2014    Standard Low On Exchange Plan    21989AK001
#
#        MarketCoverage MetalLevel NetworkId StateCode
# 0  SHOP (Small Group)        Low    AKN001        AK
# 1  SHOP (Small Group)        Low    AKN001        AK
# 2  SHOP (Small Group)       High    AKN001        AK
# 3          Individual        Low    AKN001        AK
# 4          Individual        Low    AKN001        AK

# %%
new_planAttributes_df.to_csv('new_planAttributes_df.csv')

# %%
healthplans2018= pd.read_csv('new_health.csv')
healthplans2018.drop_duplicates().head()
# Out:
#   Plan Type State Code                                Plan Marketing Name  \
# 0       PPO         AK        Premera Blue Cross Preferred Plus Gold 1500
# 1       PPO         AK      Premera Blue Cross Preferred Plus Silver 4500
# 2       PPO         AK      Premera Blue Cross Preferred Plus Bronze 6350
# 3       PPO         AK  Premera Blue Cross Preferred Plus Bronze 5250 HSA
# 4       PPO         AK  Premera Blue Cross Preferred Plus Silver 3000 HSA
#
#           Plan ID Metal Level Individual Standard Family Standard  \
# 0  38344AK0540003        Gold              $6,000         $12,000
# 1  38344AK0540006      Silver              $7,350         $14,700
# 2  38344AK0540008      Bronze              $7,350         $14,700
# 3  38344AK0540009      Bronze              $6,600         $13,200
# 4  38344AK0540010      Silver              $6,600         $13,200
#
#   Family Per Person Standard
# 0                     $6,000
# 1                     $7,350
# 2                     $7,350
# ...

# %%
#healthplans2018.to_csv('healthplans2018.csv')

# %%
dentalplans2018= pd.read_csv('new_dental.csv')
dentalplans2018.drop_duplicates().head()
# Out:
#    Plan Type State Code        Plan Marketing Name         Plan ID  \
# 0  Indemnity         AK  Delta Dental Premier Plan  21989AK0030001
# 1        PPO         AK     BESTOne Advantage Gold  74819AK0020003
# 2        PPO         AK          BESTOne Plus Gold  74819AK0020004
# 3        PPO         AK        BESTOne Plus Silver  74819AK0020005
# 4        PPO         AK       BESTOne Basic Silver  74819AK0020006
#
#   Metal Level Individual Standard Family Standard Family Per Person Standard
# 0         Low                $350            $700                       $350
# 1        High                $350            $700                       $350
# 2        High                $350            $700                       $350
# 3         Low                $350            $700                       $350
# 4         Low                $350            $700                       $350

# %%
healthshop2018= pd.read_csv('2018_healthshop.csv')
healthshop2018.drop_duplicates().head()
# Out:
#   State Code  FIPS County Code     County Name Metal Level  \
# 0         AK              2013  Aleutians East        Gold
# 1         AK              2013  Aleutians East        Gold
# 2         AK              2013  Aleutians East        Gold
# 3         AK              2013  Aleutians East      Silver
# 4         AK              2013  Aleutians East        Gold
#
#               Issuer Name  HIOS Issuer ID Plan ID (Standard Component)  \
# 0  Moda Health Plan, Inc.           73836               73836AK0700001
# 1  Moda Health Plan, Inc.           73836               73836AK0700002
# 2  Moda Health Plan, Inc.           73836               73836AK0700003
# 3  Moda Health Plan, Inc.           73836               73836AK0700004
# 4  Moda Health Plan, Inc.           73836               73836AK0700006
#
#                Plan Marketing Name Plan Type  \
# 0     Endeavor Providence Gold 500       PPO
# 1    Endeavor Providence Gold 1000       PPO
# ...

# %%
new_healthshop2018=healthshop2018.rename({'Plan ID (Standard Component)':'Plan ID','Medical Deductible - Individual - Standard':'Individual Standard',
                      'Medical Deductible - Family - Standard': 'Family Standard', 'Medical Deductible - Family (Per Person) - Standard': 'Family Per Person Standard'},axis ='columns')
new_healthshop2018.drop_duplicates()
# Out:
#       State Code  FIPS County Code     County Name      Metal Level  \
# 0             AK              2013  Aleutians East             Gold
# 1             AK              2013  Aleutians East             Gold
# 2             AK              2013  Aleutians East             Gold
# 3             AK              2013  Aleutians East           Silver
# 4             AK              2013  Aleutians East             Gold
# 5             AK              2013  Aleutians East             Gold
# 6             AK              2013  Aleutians East             Gold
# 7             AK              2013  Aleutians East           Silver
# 8             AK              2013  Aleutians East           Silver
# 9             AK              2013  Aleutians East           Silver
# 10            AK              2013  Aleutians East           Silver
# 11            AK              2013  Aleutians East           Silver
# 12            AK              2013  Aleutians East           Silver
# ...

# %%
dentalshop2018= pd.read_csv('dentalshop2018.csv')
dentalshop2018.drop_duplicates()
# Out:
#       State Code  FIPS County Code     County Name Metal Level  \
# 0             AK              2013  Aleutians East        High
# 1             AK              2013  Aleutians East        High
# 2             AK              2013  Aleutians East        High
# 3             AK              2013  Aleutians East        High
# 4             AK              2013  Aleutians East         Low
# 5             AK              2013  Aleutians East        High
# 6             AK              2013  Aleutians East         Low
# 7             AK              2013  Aleutians East         Low
# 8             AK              2016  Aleutians West        High
# 9             AK              2016  Aleutians West        High
# 10            AK              2016  Aleutians West        High
# 11            AK              2016  Aleutians West        High
# 12            AK              2016  Aleutians West         Low
# 13            AK              2016  Aleutians West        High
# ...

# %%
dentalshop2018=dentalshop2018.rename({'Plan ID (Standard Component)':'Plan ID','Medical Deductible - Individual - Standard':'Individual Standard',
                      'Medical Deductible - Family - Standard': 'Family Standard', 'Medical Deductible - Family (Per Person) - Standard': 'Family Per Person Standard'},axis ='columns')
dentalshop2018
# Out:
#       State Code  FIPS County Code     County Name Metal Level  \
# 0             AK              2013  Aleutians East        High
# 1             AK              2013  Aleutians East        High
# 2             AK              2013  Aleutians East        High
# 3             AK              2013  Aleutians East        High
# 4             AK              2013  Aleutians East         Low
# 5             AK              2013  Aleutians East        High
# 6             AK              2013  Aleutians East         Low
# 7             AK              2013  Aleutians East         Low
# 8             AK              2016  Aleutians West        High
# 9             AK              2016  Aleutians West        High
# 10            AK              2016  Aleutians West        High
# 11            AK              2016  Aleutians West        High
# 12            AK              2016  Aleutians West         Low
# 13            AK              2016  Aleutians West        High
# ...

# %%
new_healthshop2018.to_csv('new_healthshop2018.csv')

# %%
dentalshop2018.to_csv('dentalshop2018.csv')
